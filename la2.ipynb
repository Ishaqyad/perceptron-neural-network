# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishaqyad/perceptron-neural-network/blob/main/la2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
word = input("Please enter your word: ")

def summarize_count(word):
    counts = {}
    for char in word:
        counts[char] = counts.get(char, 0) + 1
    return [(char, freq) for char, freq in counts.items()]

print(summarize_count(word))
print("Contains all letters of the alphabet" if set("abcdefghijklmnopqrstuvwxyz").issubset(set(word.lower())) else "Does not contain all letters of the alphabet")





s = input("Please enter a sentence: ")

words = s.lower().split()
cnt = {}

for x in words:
    cnt[word] = cnt.get(word, 0) + 1

print(cnt)



#3-1
#Sequence types include list, tuple, range.
#They are used for ordered collection of elements.
# Out:
# Please enter your word: x
# [('x', 1)]
# Does not contain all letters of the alphabet
# Please enter a sentence: x
# {'x': 1}
